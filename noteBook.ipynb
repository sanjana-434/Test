# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("test.csv")

# %%
import piplite
await piplite.install('seaborn')
import seaborn as sns

# %%
print(df.head())
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1260          20       RL         65.0     9750   Pave   NaN      Reg
# 1  1261          60       RL          NaN    24682   Pave   NaN      IR3
# 2  1262          20       RL         80.0     9600   Pave   NaN      Reg
# 3  1263          50       RL          NaN    11250   Pave   NaN      Reg
# 4  1264          70       RL         60.0    13515   Pave  Pave      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...          80        0    NaN    NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      7    2008        WD         Normal
# 1       0      6    2009        WD         Normal
# 2       0      6    2009        WD         Normal
# 3       0     11    2009        WD         Normal
# 4       0      7    2007        WD         Normal
#
# [5 rows x 80 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             201 non-null    int64
#  1   MSSubClass     201 non-null    int64
#  2   MSZoning       201 non-null    object
#  3   LotFrontage    160 non-null    float64
#  4   LotArea        201 non-null    int64
#  5   Street         201 non-null    object
#  6   Alley          15 non-null     object
#  7   LotShape       201 non-null    object
#  8   LandContour    201 non-null    object
#  9   Utilities      201 non-null    object
#  10  LotConfig      201 non-null    object
#  11  LandSlope      201 non-null    object
#  12  Neighborhood   201 non-null    object
#  13  Condition1     201 non-null    object
#  14  Condition2     201 non-null    object
#  15  BldgType       201 non-null    object
#  16  HouseStyle     201 non-null    object
#  17  OverallQual    201 non-null    int64
#  18  OverallCond    201 non-null    int64
#  19  YearBuilt      201 non-null    int64
#  20  YearRemodAdd   201 non-null    int64
#  21  RoofStyle      201 non-null    object
#  22  RoofMatl       201 non-null    object
#  23  Exterior1st    201 non-null    object
#  24  Exterior2nd    201 non-null    object
#  25  MasVnrType     200 non-null    object
#  26  MasVnrArea     200 non-null    float64
#  27  ExterQual      201 non-null    object
#  28  ExterCond      201 non-null    object
#  29  Foundation     201 non-null    object
#  30  BsmtQual       199 non-null    object
#  31  BsmtCond       199 non-null    object
#  32  BsmtExposure   199 non-null    object
#  33  BsmtFinType1   199 non-null    object
#  34  BsmtFinSF1     201 non-null    int64
#  35  BsmtFinType2   199 non-null    object
#  36  BsmtFinSF2     201 non-null    int64
#  37  BsmtUnfSF      201 non-null    int64
#  38  TotalBsmtSF    201 non-null    int64
#  39  Heating        201 non-null    object
#  40  HeatingQC      201 non-null    object
#  41  CentralAir     201 non-null    object
#  42  Electrical     200 non-null    object
#  43  1stFlrSF       201 non-null    int64
#  44  2ndFlrSF       201 non-null    int64
#  45  LowQualFinSF   201 non-null    int64
#  46  GrLivArea      201 non-null    int64
#  47  BsmtFullBath   201 non-null    int64
#  48  BsmtHalfBath   201 non-null    int64
#  49  FullBath       201 non-null    int64
#  50  HalfBath       201 non-null    int64
#  51  BedroomAbvGr   201 non-null    int64
#  52  KitchenAbvGr   201 non-null    int64
#  53  KitchenQual    201 non-null    object
#  54  TotRmsAbvGrd   201 non-null    int64
#  55  Functional     201 non-null    object
#  56  Fireplaces     201 non-null    int64
#  57  FireplaceQu    110 non-null    object
#  58  GarageType     191 non-null    object
#  59  GarageYrBlt    191 non-null    float64
#  60  GarageFinish   191 non-null    object
#  61  GarageCars     201 non-null    int64
#  62  GarageArea     201 non-null    int64
#  63  GarageQual     191 non-null    object
#  64  GarageCond     191 non-null    object
#  65  PavedDrive     201 non-null    object
#  66  WoodDeckSF     201 non-null    int64
#  67  OpenPorchSF    201 non-null    int64
#  68  EnclosedPorch  201 non-null    int64
#  69  3SsnPorch      201 non-null    int64
#  70  ScreenPorch    201 non-null    int64
#  71  PoolArea       201 non-null    int64
#  72  PoolQC         3 non-null      object
#  73  Fence          41 non-null     object
#  74  MiscFeature    3 non-null      object
#  75  MiscVal        201 non-null    int64
#  76  MoSold         201 non-null    int64
#  77  YrSold         201 non-null    int64
#  78  SaleType       201 non-null    object
#  79  SaleCondition  201 non-null    object
# dtypes: float64(3), int64(34), object(43)
# memory usage: 91.9+ KB
# None

# %%
print(df["LotFrontage"].describe().round(2))
# Out:
# count    201.00
# mean      69.66
# std       25.71
# min       21.00
# 25%       60.00
# 50%       69.66
# 75%       78.00
# max      313.00
# Name: LotFrontage, dtype: float64

# %%
df.set_index(df["Id"])
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1260  1260          20       RL     65.00000     9750   Pave   NaN      Reg
# 1261  1261          60       RL     69.65625    24682   Pave   NaN      IR3
# 1262  1262          20       RL     80.00000     9600   Pave   NaN      Reg
# 1263  1263          50       RL     69.65625    11250   Pave   NaN      Reg
# 1264  1264          70       RL     60.00000    13515   Pave  Pave      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1456  1456          60       RL     62.00000     7917   Pave   NaN      Reg
# 1457  1457          20       RL     85.00000    13175   Pave   NaN      Reg
# 1458  1458          70       RL     66.00000     9042   Pave   NaN      Reg
# 1459  1459          20       RL     68.00000     9717   Pave   NaN      Reg
# 1460  1460          20       RL     75.00000     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                          ...
# 1260         Lvl    AllPub  ...          80        0    NaN    NaN
# 1261         Lvl    AllPub  ...           0        0    NaN    NaN
# 1262         Lvl    AllPub  ...           0        0    NaN    NaN
# 1263         Lvl    AllPub  ...           0        0    NaN    NaN
# 1264         Lvl    AllPub  ...           0        0    NaN  GdPrv
# ...          ...       ...  ...         ...      ...    ...    ...
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN  GdPrv
# 1459         Lvl    AllPub  ...           0        0    NaN    NaN
# 1460         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# Id
# 1260         NaN       0      7    2008        WD         Normal
# 1261         NaN       0      6    2009        WD         Normal
# 1262         NaN       0      6    2009        WD         Normal
# 1263         NaN       0     11    2009        WD         Normal
# 1264         NaN       0      7    2007        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1456         NaN       0      8    2007        WD         Normal
# 1457         NaN       0      2    2010        WD         Normal
# 1458        Shed    2500      5    2010        WD         Normal
# 1459         NaN       0      4    2010        WD         Normal
# 1460         NaN       0      6    2008        WD         Normal
#
# [201 rows x 80 columns]

# %%
print(df["KitchenQual"].unique())
df["KitchenQual"] = df["KitchenQual"].replace("TA","Ex")
print(df["KitchenQual"].head())
print(df["KitchenQual"].unique())
# Out:
# ['TA' 'Gd' 'Ex' 'Fa']
# 0    Ex
# 1    Ex
# 2    Ex
# 3    Ex
# 4    Ex
# Name: KitchenQual, dtype: object
# ['Ex' 'Gd' 'Fa']

# %%
df.duplicated().sum()
df.drop_duplicates()
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1260          20       RL         65.0     9750   Pave  Pave      Reg
# 1    1261          60       RL          NaN    24682   Pave  Pave      IR3
# 2    1262          20       RL         80.0     9600   Pave  Pave      Reg
# 3    1263          50       RL          NaN    11250   Pave  Pave      Reg
# 4    1264          70       RL         60.0    13515   Pave  Pave      Reg
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 196  1456          60       RL         62.0     7917   Pave  Pave      Reg
# 197  1457          20       RL         85.0    13175   Pave  Pave      Reg
# 198  1458          70       RL         66.0     9042   Pave  Pave      Reg
# 199  1459          20       RL         68.0     9717   Pave  Pave      Reg
# 200  1460          20       RL         75.0     9937   Pave  Pave      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0           Lvl    AllPub  ...          80        0    NaN    NaN         NaN
# 1           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 3           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# ..          ...       ...  ...         ...      ...    ...    ...         ...
# 196         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 197         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 198         Lvl    AllPub  ...           0        0    NaN  GdPrv        Shed
# 199         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 200         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         0      7    2008        WD         Normal
# 1         0      6    2009        WD         Normal
# 2         0      6    2009        WD         Normal
# 3         0     11    2009        WD         Normal
# 4         0      7    2007        WD         Normal
# ..      ...    ...     ...       ...            ...
# 196       0      8    2007        WD         Normal
# 197       0      2    2010        WD         Normal
# 198    2500      5    2010        WD         Normal
# 199       0      4    2010        WD         Normal
# 200       0      6    2008        WD         Normal
#
# [201 rows x 80 columns]

# %%
s = df.loc[df["Alley"].notnull(),"Alley"]

print(s)
# Out:
# 4      Pave
# 58     Pave
# 69     Grvl
# 78     Grvl
# 90     Pave
# 105    Pave
# 118    Grvl
# 121    Grvl
# 128    Grvl
# 134    Pave
# 145    Grvl
# 155    Pave
# 168    Grvl
# 173    Grvl
# 195    Pave
# Name: Alley, dtype: object

# %%
df["Alley"] = df["Alley"].fillna(method = 'bfill')
df["Alley"] = df["Alley"].fillna(method = 'ffill')
df["Alley"]
df.dropna(how = "all")
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1260          20       RL         65.0     9750   Pave  Pave      Reg
# 1    1261          60       RL          NaN    24682   Pave  Pave      IR3
# 2    1262          20       RL         80.0     9600   Pave  Pave      Reg
# 3    1263          50       RL          NaN    11250   Pave  Pave      Reg
# 4    1264          70       RL         60.0    13515   Pave  Pave      Reg
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 196  1456          60       RL         62.0     7917   Pave  Pave      Reg
# 197  1457          20       RL         85.0    13175   Pave  Pave      Reg
# 198  1458          70       RL         66.0     9042   Pave  Pave      Reg
# 199  1459          20       RL         68.0     9717   Pave  Pave      Reg
# 200  1460          20       RL         75.0     9937   Pave  Pave      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0           Lvl    AllPub  ...          80        0    NaN    NaN         NaN
# 1           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 3           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# ..          ...       ...  ...         ...      ...    ...    ...         ...
# 196         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 197         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 198         Lvl    AllPub  ...           0        0    NaN  GdPrv        Shed
# 199         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 200         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         0      7    2008        WD         Normal
# 1         0      6    2009        WD         Normal
# 2         0      6    2009        WD         Normal
# 3         0     11    2009        WD         Normal
# 4         0      7    2007        WD         Normal
# ..      ...    ...     ...       ...            ...
# 196       0      8    2007        WD         Normal
# 197       0      2    2010        WD         Normal
# 198    2500      5    2010        WD         Normal
# 199       0      4    2010        WD         Normal
# 200       0      6    2008        WD         Normal
#
# [201 rows x 80 columns]

# %%
print(df["Fence"].isnull().sum())
# Out:
# 160

# %%
print(df["LotFrontage"].describe()['25%'])
df["LotFrontage"].plot(kind = 'box',vert = False)
# Out:
# 60.0
# <AxesSubplot:>

# %%
fig = plt.figure(figsize = (10,6))
plt.boxplot(x = df["LotFrontage"],vert = False)
plt.show()

# %%
sns.distplot(df["LotFrontage"],kde = False)
# Out:
# <ipython-input-116-76e91a604e5b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["LotFrontage"],kde = False)
# <AxesSubplot:xlabel='LotFrontage'>

# %%
sns.distplot(df["LotFrontage"],hist =False)
# Out:
# <ipython-input-214-ef75af784eeb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["LotFrontage"],hist =False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[214], line 2
#       1 sns.distplot(df["LotFrontage"],hist =False)
# ----> 2 plt.fill_between(color = 'b')
#
# TypeError: fill_between() missing 2 required positional arguments: 'x' and 'y1'

# %%
df["KitchenQual"].value_counts().plot(kind ='pie',colors = ["pink","green","yellow","orange"],figsize = (2,2))
# Out:
# <AxesSubplot:ylabel='KitchenQual'>

# %%
ax = df["KitchenQual"].value_counts().plot(kind ='bar',figsize = (2,2))
ax.set_xlabel("KitchenQual")
ax.set_title("kjern")
# Out:
# Text(0.5, 1.0, 'kjern')

# %%
#stacked bar plot
x1 = df["KitchenQual"].value_counts().index
y1=df["KitchenQual"].value_counts()
#x2 = df["Electrical"]
y2= np.array([34,56,76])

plt.bar(x1,y1)
plt.bar(x1 ,y2,bottom = y1)
plt.show()

# %%
#x1 = df["KitchenQual"].value_counts().index
x1 = np.array([0,1,2])
y1=df["KitchenQual"].value_counts()
#x2 = df["Electrical"]
y2= np.array([34,56,76])


plt.bar(x1-0.2,y1,width = 0.4)
plt.bar(x1+0.2 ,y2,width = 0.4)
plt.xticks(ticks = x1,labels = np.array(df["KitchenQual"].value_counts().index))
plt.show()

# %%
fig,ax = plt.subplots()
sns.distplot(df["LotFrontage"])
ax.axvline(df["LotFrontage"].mean(),color = 'r')
plt.show()
# Out:
# <ipython-input-126-83f54d2b2092>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["LotFrontage"])

# %%
#s = (df.loc[df["LotFrontage"].notnull(),"LotFrontage"])
#print(s)

#s = df["LotFrontage"].dropna()
#s

i = df[df["LotFrontage"].isnull()].index
df.drop(i,inplace = True)
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1260          20       RL         65.0     9750   Pave   NaN      Reg
# 2    1262          20       RL         80.0     9600   Pave   NaN      Reg
# 4    1264          70       RL         60.0    13515   Pave  Pave      Reg
# 5    1265         120       RH         34.0     4060   Pave   NaN      Reg
# 6    1266         160       FV         35.0     3735   Pave   NaN      Reg
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 196  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 197  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 198  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 199  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 200  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0           Lvl    AllPub  ...          80        0    NaN    NaN         NaN
# 2           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 5           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 6           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# ..          ...       ...  ...         ...      ...    ...    ...         ...
# 196         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 197         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 198         Lvl    AllPub  ...           0        0    NaN  GdPrv        Shed
# 199         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 200         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         0      7    2008        WD         Normal
# 2         0      6    2009        WD         Normal
# 4         0      7    2007        WD         Normal
# 5         0      8    2008       COD        Abnorml
# 6         0      3    2006        WD         Normal
# ..      ...    ...     ...       ...            ...
# 196       0      8    2007        WD         Normal
# 197       0      2    2010        WD         Normal
# 198    2500      5    2010        WD         Normal
# 199       0      4    2010        WD         Normal
# 200       0      6    2008        WD         Normal
#
# [160 rows x 80 columns]

# %%
print(df.shape)
# Out:
# (0, 80)

# %%
print(df.head())
df["LotFrontage"] = df["LotFrontage"].fillna(df["LotFrontage"].mean())
print(df.head())
print(df["LotFrontage"].isnull().sum())
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1260          20       RL     65.00000     9750   Pave   NaN      Reg
# 1  1261          60       RL     69.65625    24682   Pave   NaN      IR3
# 2  1262          20       RL     80.00000     9600   Pave   NaN      Reg
# 3  1263          50       RL     69.65625    11250   Pave   NaN      Reg
# 4  1264          70       RL     60.00000    13515   Pave  Pave      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...          80        0    NaN    NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      7    2008        WD         Normal
# 1       0      6    2009        WD         Normal
# 2       0      6    2009        WD         Normal
# 3       0     11    2009        WD         Normal
# 4       0      7    2007        WD         Normal
#
# [5 rows x 80 columns]
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1260          20       RL     65.00000     9750   Pave   NaN      Reg
# 1  1261          60       RL     69.65625    24682   Pave   NaN      IR3
# 2  1262          20       RL     80.00000     9600   Pave   NaN      Reg
# 3  1263          50       RL     69.65625    11250   Pave   NaN      Reg
# 4  1264          70       RL     60.00000    13515   Pave  Pave      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...          80        0    NaN    NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      7    2008        WD         Normal
# 1       0      6    2009        WD         Normal
# 2       0      6    2009        WD         Normal
# 3       0     11    2009        WD         Normal
# 4       0      7    2007        WD         Normal
#
# [5 rows x 80 columns]
# 0

# %%
corr = df.corr()
col = df.select_dtypes(include = ['int64']).columns
print(col)
for i in col:
    for j in col:
        if (i!=j):
            if (corr[i][j] >0.8):
                print(i ," [ ] " ,j ,corr[i][j])
# Out:
# <ipython-input-88-91dbaa234c63>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'],
#       dtype='object')
# TotalBsmtSF  [ ]  1stFlrSF 0.8698864254673779
# 1stFlrSF  [ ]  TotalBsmtSF 0.8698864254673779
# GrLivArea  [ ]  TotRmsAbvGrd 0.8056808614414835
# TotRmsAbvGrd  [ ]  GrLivArea 0.8056808614414835
# GarageCars  [ ]  GarageArea 0.8603148296847154
# GarageArea  [ ]  GarageCars 0.8603148296847154

# %%
h = sns.heatmap(corr,cmap="YlGnBu")
h.set_title("Correlation",fontdict = {"fontsize":10})
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
x_ = df["2ndFlrSF"]
x_ = np.array(x_)
print(x_)
print(x.isnull().sum())
# Out:
# [   0  783    0  684  764    0  739  925    0 1479  650  192    0    0
#     0  589  992  660    0  903  430    0    0    0  912  748  587    0
#     0    0  850    0  672  994  832    0    0    0    0  950    0  978
#   741 1323    0  732    0    0    0    0    0    0    0 1357 1177    0
#  1020    0    0    0    0    0    0  862    0    0    0    0    0 1208
#   677    0    0    0  557  600    0    0    0  941    0    0    0  885
#   741  728    0    0    0    0 1215 1296  858  390 1185  873  698    0
#     0  804    0 1611    0  457  796  600  860  908  550    0    0  534
#     0  989    0  932    0    0  620  504  640    0    0  764    0  560
#   358 1392  862    0  349    0    0    0  691    0 1349    0  574  768
#   448  208  729    0    0  520    0    0    0  622  857  896  556    0
#     0  795    0 1044 1140    0    0  708    0    0  626    0    0  904
#   510    0    0 1104    0    0  830    0    0    0    0    0  685  748
#     0  981    0    0    0    0  870  550    0  896    0    0    0    0
#   694    0 1152    0    0]
# 0

# %%
y_ = df["GrLivArea"]
y_ = np.array(y_)
print(y.isnull().sum())
print(y_)
# Out:
# 2ndFlrSF     0
# GrLivArea    0
# dtype: int64
# [1054 1675 1050 1788 1824 1337 1452 1889 2018 3447 1524 1524 1489  935
#  1357 1250 1920 1395 1724 2031 1128 1573 1339 1040 1824 2447 1412 1328
#  1582 1659 1970 1152 1302 2372 1664  864 1052 1128 1072 5642 1246 1983
#  1494 2526 1616 1708 1652 1368  990 1122 1294 1902 1274 2810 2599  948
#  2112 1630 1352 1787  948 1478  720 1923  708 1795  796  774  816 2792
#  1632 1588  954  816 1360 1365 1334 1656  693 1861  864  872 1114 2169
#  1913 1456  960 2156 1776 1494 2358 2634 1716 1176 3238 1865 1920  892
#  1078 1573 1980 2601 1530 1738 1412 1200 1674 1790 1475  848 1668 1374
#  1661 2097 2633 1958 1571  790 1604  987 1394  864 2117 1762 1416 1258
#  1154 2784 2526 1746 1218 1525 1584  900 1912 1500 2482 1687 1513 1904
#  1608 1158 1593 1294 1464 1214 1646  768  833 1363 2093 1840 1668 1040
#  1844 1848 1569 2290 2450 1144 1844 1416 1069  848 2201 1344 1252 2127
#  1558  804 1440 1838  958  968 1792 1126 1537  864 1932 1236 1725 2555
#   848 2007  952 1422  913 1188 2090 1346  630 1792 1578 1072 1140 1221
#  1647 2073 2340 1078 1256]

# %%
sample = df[["2ndFlrSF","GrLivArea"]]
print(sample.corr())
# Out:
#            2ndFlrSF  GrLivArea
# 2ndFlrSF   1.000000   0.658253
# GrLivArea  0.658253   1.000000

# %%
df.plot(kind = 'scatter',x = "2ndFlrSF",y="GrLivArea")
#plt.scatter(x_,y_)
plt.show()

# %%
reg = np.polyfit(x_,y_,deg = 1)
reg
# Out:
# array([8.79783396e-01, 1.23659139e+03])

# %%
trend = np.polyval(reg,x_)
print(trend)
# Out:
# [1236.59138525 1925.461784   1236.59138525 1838.36322784 1908.74589948
#  1236.59138525 1886.75131459 2050.39102617 1236.59138525 2537.79102733
#  1808.45059239 1405.50979721 1236.59138525 1236.59138525 1236.59138525
#  1754.78380525 2109.33651368 1817.24842634 1236.59138525 2031.03579147
#  1614.89824536 1236.59138525 1236.59138525 1236.59138525 2038.95384203
#  1894.66936515 1753.02423846 1236.59138525 1236.59138525 1236.59138525
#  1984.4072715  1236.59138525 1827.80582709 2111.09608047 1968.57117038
#  1236.59138525 1236.59138525 1236.59138525 1236.59138525 2072.38561106
#  1236.59138525 2097.01954614 1888.51088138 2400.54481762 1236.59138525
#  1880.59283082 1236.59138525 1236.59138525 1236.59138525 1236.59138525
#  1236.59138525 1236.59138525 1236.59138525 2430.45745307 2272.09644186
#  1236.59138525 2133.97044875 1236.59138525 1236.59138525 1236.59138525
#  1236.59138525 1236.59138525 1236.59138525 1994.96467225 1236.59138525
#  1236.59138525 1236.59138525 1236.59138525 1236.59138525 2299.36972712
#  1832.20474407 1236.59138525 1236.59138525 1236.59138525 1726.6307366
#  1764.46142261 1236.59138525 1236.59138525 1236.59138525 2064.4675605
#  1236.59138525 1236.59138525 1236.59138525 2015.19969035 1888.51088138
#  1877.07369724 1236.59138525 1236.59138525 1236.59138525 1236.59138525
#  2305.52821089 2376.79066594 1991.44553867 1579.70690953 2279.13470903
#  2004.6422896  1850.68019537 1236.59138525 1236.59138525 1943.93723531
#  1236.59138525 2653.92243555 1236.59138525 1638.65239704 1936.89896814
#  1764.46142261 1993.20510546 2035.43470845 1720.47225283 1236.59138525
#  1236.59138525 1706.3957185  1236.59138525 2106.69716349 1236.59138525
#  2056.54950994 1236.59138525 1236.59138525 1782.05709052 1680.00221663
#  1799.65275843 1236.59138525 1236.59138525 1908.74589948 1236.59138525
#  1729.27008678 1551.55384087 2461.24987191 1994.96467225 1236.59138525
#  1543.63579031 1236.59138525 1236.59138525 1236.59138525 1844.5217116
#  1236.59138525 2423.4191859  1236.59138525 1741.58705432 1912.26503306
#  1630.73434648 1419.58633153 1877.95348064 1236.59138525 1236.59138525
#  1694.07875096 1236.59138525 1236.59138525 1236.59138525 1783.81665731
#  1990.56575527 2024.8773077  1725.7509532  1236.59138525 1236.59138525
#  1936.01918475 1236.59138525 2155.08525025 2239.54445622 1236.59138525
#  1236.59138525 1859.47802933 1236.59138525 1236.59138525 1787.33579089
#  1236.59138525 1236.59138525 2031.91557487 1685.280917   1236.59138525
#  1236.59138525 2207.87225398 1236.59138525 1236.59138525 1966.81160359
#  1236.59138525 1236.59138525 1236.59138525 1236.59138525 1236.59138525
#  1839.24301123 1894.66936515 1236.59138525 2099.65889633 1236.59138525
#  1236.59138525 1236.59138525 1236.59138525 2002.00293942 1720.47225283
#  1236.59138525 2024.8773077  1236.59138525 1236.59138525 1236.59138525
#  1236.59138525 1847.16106179 1236.59138525 2250.10185697 1236.59138525
#  1236.59138525]

# %%
plt.plot(x_,trend,color = 'r',label = "y_pred")
plt.scatter(x_,y_,label = "y")
plt.legend()

plt.show()

# %%
np.polyval(reg,[200,800])
# Out:
# array([1412.54806437, 1940.41810172])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[271], line 1
# ----> 1 help(colors)
#
# NameError: name 'colors' is not defined
